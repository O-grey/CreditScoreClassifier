# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

data=pd.read_csv('Cleaned_CSC&R_Dataset.csv')
data
# Out:
#        Age Occupation  Annual_Income  Monthly_Inhand_Salary  \
# 0       23  Scientist       19114.12            1824.843333
# 1       23  Scientist       19114.12            3095.978333
# 2       23  Scientist       19114.12            3095.978333
# 3       23  Scientist       19114.12            1824.843333
# 4       23  Scientist       19114.12            3095.978333
# ...    ...        ...            ...                    ...
# 93428   25   Mechanic       39628.99            3359.415833
# 93429   25   Mechanic       39628.99            3359.415833
# 93430   25   Mechanic       39628.99            3359.415833
# 93431   25   Mechanic       39628.99            3359.415833
# 93432   25   Mechanic       39628.99            3359.415833
#
#        Num_Bank_Accounts  Num_Credit_Card  Interest_Rate  Num_of_Loan  \
# 0                      3              4.0              3            4
# 1                      3              4.0              3            4
# ...

# %% [markdown]
# # Checking for duplicated value (if any).If found remove it using data=data[~data.duplicated()]

# %%
data[data.duplicated()]
#No duplicated found
# Out:
# Empty DataFrame
# Columns: [Age, Occupation, Annual_Income, Monthly_Inhand_Salary, Num_Bank_Accounts, Num_Credit_Card, Interest_Rate, Num_of_Loan, Type_of_Loan, Delay_from_due_date, Num_of_Delayed_Payment, Changed_Credit_Limit, Num_Credit_Inquiries, Credit_Mix, Outstanding_Debt, Credit_Utilization_Ratio, Credit_History_Age, Payment_of_Min_Amount, Total_EMI_per_month, Amount_invested_monthly, Payment_Behaviour, Monthly_Balance, Credit_Score]
# Index: []
#
# [0 rows x 23 columns]

# %%
data.select_dtypes(exclude='O').corr() ##Finding correlations in numerical columns
# Out:
#                                Age  Annual_Income  Monthly_Inhand_Salary  \
# Age                       1.000000       0.088920               0.081202
# Annual_Income             0.088920       1.000000               0.873204
# Monthly_Inhand_Salary     0.081202       0.873204               1.000000
# Num_Bank_Accounts        -0.178102      -0.256581              -0.242904
# Num_Credit_Card          -0.136919      -0.191570              -0.182076
# Interest_Rate            -0.199996      -0.267928              -0.254608
# Num_of_Loan              -0.207159      -0.240465              -0.225908
# Delay_from_due_date      -0.175918      -0.242620              -0.230014
# Num_of_Delayed_Payment    0.000881       0.001856               0.001690
# Changed_Credit_Limit     -0.154879      -0.165132              -0.157746
# Num_Credit_Inquiries     -0.005714      -0.007917              -0.007606
# Outstanding_Debt         -0.206896      -0.264068              -0.251529
# ...

# %% [markdown]
# ## **Visualizations**

# %%
  # Visualize correlation matrix
plt.figure(figsize=(25, 20))
sns.heatmap( data.select_dtypes(exclude='O').corr(), annot=True)
plt.show()

# %%
data.columns
# Out:
# Index(['Age', 'Occupation', 'Annual_Income', 'Monthly_Inhand_Salary',
#        'Num_Bank_Accounts', 'Num_Credit_Card', 'Interest_Rate', 'Num_of_Loan',
#        'Type_of_Loan', 'Delay_from_due_date', 'Num_of_Delayed_Payment',
#        'Changed_Credit_Limit', 'Num_Credit_Inquiries', 'Credit_Mix',
#        'Outstanding_Debt', 'Credit_Utilization_Ratio', 'Credit_History_Age',
#        'Payment_of_Min_Amount', 'Total_EMI_per_month',
#        'Amount_invested_monthly', 'Payment_Behaviour', 'Monthly_Balance',
#        'Credit_Score'],
#       dtype='object')

# %%
data.drop(['Type_of_Loan','Delay_from_due_date','Num_of_Delayed_Payment','Changed_Credit_Limit','Credit_History_Age',
           'Monthly_Balance','Num_Bank_Accounts','Total_EMI_per_month','Occupation','Age','Num_Credit_Card'],axis=1,inplace=True)

# %%
data

##This Data we will be using for predicting Credit score(classification problem) and Credit Utilization Ratio(regression problem)
# Out:
#        Annual_Income  Monthly_Inhand_Salary  Interest_Rate  Num_of_Loan  \
# 0           19114.12            1824.843333              3            4
# 1           19114.12            3095.978333              3            4
# 2           19114.12            3095.978333              3            4
# 3           19114.12            1824.843333              3            4
# 4           19114.12            3095.978333              3            4
# ...              ...                    ...            ...          ...
# 93428       39628.99            3359.415833              7            2
# 93429       39628.99            3359.415833              7            2
# 93430       39628.99            3359.415833             38            2
# 93431       39628.99            3359.415833              7            2
# 93432       39628.99            3359.415833              7            2
#
#        Num_Credit_Inquiries Credit_Mix  Outstanding_Debt  \
# ...

# %%
data.describe()
# Out:
#        Annual_Income  Monthly_Inhand_Salary  Interest_Rate   Num_of_Loan  \
# count   93433.000000           93433.000000   93433.000000  93433.000000
# mean    51273.116572            4030.776705      15.016044      3.570655
# std     38701.129338            2961.952841       9.259105      2.495668
# min      7005.930000             303.645417       1.000000      0.000000
# 25%     19457.500000            1794.572500       8.000000      2.000000
# 50%     37577.820000            3095.978333      13.000000      3.000000
# 75%     72817.020000            5375.322500      20.000000      5.000000
# max    152844.112500           15204.633330      38.000000     11.000000
#
#        Num_Credit_Inquiries  Outstanding_Debt  Credit_Utilization_Ratio  \
# count          93433.000000      93433.000000              93433.000000
# mean              27.431539       1400.980863                 32.288198
# std              191.559699       1087.240833                  5.116127
# ...

# %% [markdown]
# # **Univariate Analysis**

# %%
## Proportion of count data on numerical columns
plt.figure(figsize=(15, 15))
plt.suptitle('Univariate Analysis of Numerical Features', fontsize=20, fontweight='bold', alpha=0.8, y=1.)
numeric_features=data.select_dtypes(exclude='O').columns
for i in range(0, len(numeric_features)):
    plt.subplot(5, 3, i+1)
    sns.kdeplot(x=data[numeric_features[i]],shade=True, color='r')
    plt.xlabel(numeric_features[i])
    plt.tight_layout()
# Out:
# <ipython-input-247-842c3adff9d6>:7: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(x=data[numeric_features[i]],shade=True, color='r')
# <ipython-input-247-842c3adff9d6>:7: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(x=data[numeric_features[i]],shade=True, color='r')
# <ipython-input-247-842c3adff9d6>:7: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(x=data[numeric_features[i]],shade=True, color='r')
# <ipython-input-247-842c3adff9d6>:7: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
# ...

# %% [markdown]
# ##Insights:
#
# 1.   Graphs represents the presence of skewness and outliers in the data set.
# 2.  Credit Utilization ratio,Monthly Invested Amount,Number of credit inquiries has more or less Normal Distribution.
# 3.  Number of loans is heavily skewed where as Outstanding debt,Monthly Inhand Salary,Annual Income has some skewness present in dataset

# %%
# categorical columns
plt.figure(figsize=(20, 15))
plt.suptitle('Univariate Analysis of Categorical Features', fontsize=20, fontweight='bold', alpha=0.8, y=1.)
category = data.select_dtypes(include='O').columns
for i in range(0, len(category)):
    plt.subplot(2, 2, i+1)
    sns.countplot(x=data[category[i]],palette="Set2")
    plt.xlabel(category[i])
    plt.xticks(rotation=45)
    plt.tight_layout()
# Out:
# <ipython-input-248-a8709ec26025>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=data[category[i]],palette="Set2")
# <ipython-input-248-a8709ec26025>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=data[category[i]],palette="Set2")
# <ipython-input-248-a8709ec26025>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=data[category[i]],palette="Set2")
# <ipython-input-248-a8709ec26025>:7: FutureWarning:
#
# ...

# %% [markdown]
# ## Insights
#
#
# 1.   Categorical dataset is unbalanced.
# 2. Credit score has more 'standard' value counts.
# 3.  Payment Behaviour has more 'Low Spent Small Value Payments' value counts.
# 4.  Payment of Minimum amount  has certain number of 'Not Mentioned' value counts.

# %%
##Pie Chart for Visualizing credit score value counts more properly

data['Credit_Score'].value_counts().plot.pie(y=data['Credit_Score'],figsize=(10,12),autopct='%1.1f')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ## Multivariate **Analysis**

# %%
##pairplot
sns.pairplot(data)

# %%
data
# Out:
#        Annual_Income  Monthly_Inhand_Salary  Interest_Rate  Num_of_Loan  \
# 0           19114.12            1824.843333              3            4
# 1           19114.12            3095.978333              3            4
# 2           19114.12            3095.978333              3            4
# 3           19114.12            1824.843333              3            4
# 4           19114.12            3095.978333              3            4
# ...              ...                    ...            ...          ...
# 93428       39628.99            3359.415833              7            2
# 93429       39628.99            3359.415833              7            2
# 93430       39628.99            3359.415833             38            2
# 93431       39628.99            3359.415833              7            2
# 93432       39628.99            3359.415833              7            2
#
#        Num_Credit_Inquiries Credit_Mix  Outstanding_Debt  \
# ...
